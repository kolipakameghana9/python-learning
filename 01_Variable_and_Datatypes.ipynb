# %% [markdown]
#  VARIABLE AND DATA TYPES,

# %%
# x is a variable that holds the value 5

x=5
print(x)
# Out:
# 5

# %%
# data types examples
a="a" # string
type("a")
print(type("a")) # to check the data type of a variable
b=5
print(type(b)) 
c=5.5
print(type(c))
d=True
print(type(d))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name="ravi"
type(name)
# Out:
# str

# %%
b=1.5
print(type(b))
# Out:
# <class 'float'>

# %%
True
# Out:
# True

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
False
print(type(False))
# Out:
# <class 'bool'>
