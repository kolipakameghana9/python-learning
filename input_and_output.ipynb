# %% [markdown]
# Input and Output

# %%
print("hello world")
# Out:
# hello world

# %%
print(10)
print(3.4)
# Out:
# 10
# 3.4

# %% [markdown]
# printing variables

# %%
a=10
b=20
print(a)
print(b)
print(a,b)
# Out:
# 10
# 20
# 10 20

# %%
name="meera"
age=23
print(name)
print(age)
# Out:
# meera
# 23

# %% [markdown]
# separator(sep)

# %%
print("kichen","hall","balcony")
# Out:
# kichen hall balcony

# %%
print("kichen","hall","balcony",sep="-")
# Out:
# kichen-hall-balcony

# %% [markdown]
# end parameter

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello",end=" ")
print("world")
# Out:
# hello world

# %%
name=input("enter your name:")
print(name)
# Out:
# meera

# %%
age=int(input("enter your age:"))
print(age)
# Out:
# 23

# %%
salary=float(input("enter your salary:"))
print(salary)
# Out:
# 50000.45
