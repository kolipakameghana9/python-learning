# %% [markdown]
# string formatting

# %%
name="meera"
age=23
print("my name is",name)
# Out:
# my name is meera

# %%
name="meera"
age=23
print("my name is "  + name)
# Out:
# my name is meera

# %%
print("my name is",name, "my age is",age )
# Out:
# my name is meera my age is 23

# %%
location="hyderabad"
salary=51000
print("I stay in",location,"my salary is",salary)
# Out:
# I stay in hyderabad my salary is 51000

# %%
#f-strings
name="meera" 
print(f"my name is {name}")
# Out:
# my name is meera

# %%
print(f"my name is {name} my age is {age} ")
# Out:
# my name is meera my age is 23

# %%
a=10
b=10
print(f"sum={a+b}")
# Out:
# sum=20

# %%
a=10
b=10
print("sum=",a+b)
# Out:
# sum= 20

# %%
a=20
print(f"square={a**2}")
# Out:
# square=400

# %%
#decimal formatting
pi=3.14159
print(f"{pi:.2f}")
# Out:
# 3.14

# %%
#function calls
name="meera"
print(f"{name.upper()}")
# Out:
# MEERA

# %%
country="India"
print(f"{country.upper()}")
# Out:
# INDIA

# %%
name="jaya"
print(f"my name is {name}")
# Out:
# my name is jaya

# %%
age=21
print(f"I am {age} years old")
# Out:
# I am 21 years old

# %%
name="jaya"
college="JNTU"
print(F"my name is {name} I study at {college} college")
# Out:
# my name is jaya I study at JNTU college

# %%
language="python"
duration=6
print(f"I will learn {language} for {duration} months")
# Out:
# I will learn python for 6 months

# %%
a=30
b=40
print(f"sum={a+b}")
# Out:
# sum=70

# %%
num=8
print(f"square of 8 is {num**2}")
# Out:
# square of 8 is 64

# %%
length=5
weadth=4 
print(f"area={length*weadth}")
# Out:
# area=20

# %%
#user input+ f strings
name=input("enter your name:")
print(f"my name is {name}")
# Out:
# my name is meghana

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
print(f"sum={a+b}")
# Out:
# sum=70

# %%
a=3.333333
print(f"a={a:.3f}")
# Out:
# a=3.333

# %%
name="jayasree"
print(f"name={name.upper()}")
# Out:
# name=JAYASREE

# %%
name="jayasree"
print(f"{name.upper()}")
# Out:
# JAYASREE

# %%
name="meghana"
print(f"length of name is {(len(name))}")
# Out:
# length of name is 7

# %%
name="jaya"
maths=int(input("enter maths marks"))
science=int(input("enter science marks"))
english=int(input("enter english marks"))
print(f"average marks={(maths+science+english)/3:.2f}")
# Out:
# average marks=80.00

# %%
cube=int(input("enter a number:"))
print(f"the cube of {cube} is {cube**3}")
# Out:
# the cube of 7 is 343

# %%
name="jaya"
age=21
city="hyderabad"
course="python"
print(f"name  :{name} \nage   :{age} \ncity  :{city} \ncourse:{course}")
# Out:
# name  :jaya
# age   :21
# city  :hyderabad
# course:python

# %%
print(f"""------student profile ---------
   
   name  :{name}
   age   :{age} 
   city  :{city}
   course:{course}
   -------------------------""")
# Out:
# ------student profile ---------
#
#    name  :jaya
#    age   :21
#    city  :hyderabad
#    course:python
#    -------------------------
